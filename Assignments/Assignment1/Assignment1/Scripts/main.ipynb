# %% [markdown]
# Import Packages

# %%
import data_preprocessor as dp
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
#import data 
messy_data = pd.read_csv('../Data/messy_data.csv')
clean_data = messy_data.copy()

# %% [markdown]
# Preform data exploration

# %%
clean_data = messy_data.copy()
clean_data.head()
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1196 entries, 0 to 1195
# Data columns (total 28 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  920 non-null    float64
#  1   a       1193 non-null   object
#  2   b       1196 non-null   float64
#  3   c       1196 non-null   int64
#  4   d       561 non-null    object
#  5   e       1196 non-null   object
#  6   f       1196 non-null   float64
#  7   g       1196 non-null   object
#  8   h       1158 non-null   float64
#  9   i       1087 non-null   object
#  10  j       591 non-null    float64
#  11  k       1196 non-null   float64
#  12  l       1196 non-null   float64
#  13  m       778 non-null    object
#  14  n       1012 non-null   float64
#  15  o       1008 non-null   float64
#  16  p       1122 non-null   float64
#  17  q       1009 non-null   float64
#  18  r       1196 non-null   float64
#  19  s       1196 non-null   object
#  20  t       1110 non-null   float64
#  21  u       1079 non-null   float64
#  22  v       1116 non-null   float64
#  23  w       1079 non-null   float64
#  24  x       397 non-null    float64
#  25  y       1196 non-null   float64
#  26  z       598 non-null    float64
#  27  {       1122 non-null   object
# dtypes: float64(19), int64(1), object(8)
# memory usage: 261.8+ KB

# %%
clean_data.describe()
# Out:
#            target            b            c            f            h  \
# count  920.000000  1196.000000  1196.000000  1196.000000  1158.000000
# mean     0.553261     0.004015    53.383779     0.001391   200.583765
# std      0.497426     0.984837     9.534033     1.011656   110.061582
# min      0.000000    -3.308750    28.000000    -2.820047     0.000000
# 25%      0.000000    -0.692960    47.000000    -0.633350   176.250000
# 50%      1.000000     0.004241    54.000000    -0.051965   224.000000
# 75%      1.000000     0.714572    60.000000     0.693539   270.000000
# max      1.000000     2.982511    77.000000     3.323155   603.000000
#
#                 j            k            l            n            o  \
# count  591.000000  1196.000000  1196.000000  1012.000000  1008.000000
# mean    -0.600216     0.007269    -0.013268     4.904847   137.780754
# std      1.067309     2.498874     0.958741     0.200283    26.175380
# min     -5.954661   -24.268796    -2.802329     4.094345    60.000000
# 25%     -1.113061    -0.722036    -0.636907     4.787492   120.000000
# 50%     -0.324872     0.002258    -0.000074     4.941642   140.000000
# 75%      0.136188     0.699648     0.642745     5.062595   157.000000
# max      1.369476    27.315031     3.328148     5.273000   202.000000
#
#                  p            q            r            t            u  \
# count  1122.000000  1009.000000  1196.000000  1110.000000  1079.000000
# mean    137.660298   137.259233    53.376221     0.872252    53.328760
# std      25.890960    25.790053     9.603964     1.077211     9.645423
# min      60.522848    60.035804    27.548190    -2.600000    28.743286
# 25%     119.742012   119.041270    46.857255     0.000000    46.541317
# 50%     139.676137   139.602369    54.126896     0.500000    54.148423
# 75%     157.382495   156.970305    60.324072     1.500000    60.418600
# max     200.680509   202.572685    77.484697     6.200000    78.520864
#
#                  v            w           x            y           z
# count  1116.000000  1079.000000  397.000000  1196.000000  598.000000
# mean    132.247312     0.034028    0.667506    53.379991   -0.757779
# std      18.872281     0.995701    0.924021     9.564497    1.257376
# min       0.000000    -3.087673    0.000000    26.549257   -7.293222
# 25%     120.000000    -0.601836    0.000000    46.931375   -1.316941
# 50%     130.000000     0.035589    0.000000    54.448992   -0.439484
# 75%     140.000000     0.723486    1.000000    59.812460    0.094453
# max     200.000000     3.933288    3.000000    79.712348    1.202416

# %%
clean_data.shape
# Out:
# (1196, 28)

# %%
# view missing values
missing_data = clean_data.isnull().sum()
print(missing_data)
# Out:
# target    276
# a           3
# b           0
# c           0
# d         635
# e           0
# f           0
# g           0
# h          38
# i         109
# j         605
# k           0
# l           0
# m         418
# n         184
# o         188
# p          74
# q         187
# r           0
# s           0
# t          86
# u         117
# v          80
# w         117
# x         799
# y           0
# z         598
# {          74
# dtype: int64

# %%
# 2. Preprocess the data
clean_data = dp.impute_missing_values(clean_data, strategy='mean')
missing_data = clean_data.isnull().sum()
print(missing_data)
clean_data = dp.remove_duplicates(clean_data)
clean_data = dp.normalize_data(clean_data)
#clean_data = dp.remove_redundant_features(clean_data)
# Out:
# target    0
# a         0
# b         0
# c         0
# d         0
# e         0
# f         0
# g         0
# h         0
# i         0
# j         0
# k         0
# l         0
# m         0
# n         0
# o         0
# p         0
# q         0
# r         0
# s         0
# t         0
# u         0
# v         0
# w         0
# x         0
# y         0
# z         0
# {         0
# dtype: int64

# %%
clean_data.shape
clean_data.head()
# Out:
#    target               a         b         c                  d          e  \
# 0     0.0  lv hypertrophy  0.610389  0.714286       fixed defect  Cleveland
# 1     1.0  lv hypertrophy  0.358036  0.795918             normal  Cleveland
# 2     1.0  lv hypertrophy  0.595613  0.795918  reversable defect  Cleveland
# 3     0.0          normal  0.301262  0.183673             normal  Cleveland
# 4     0.0  lv hypertrophy  0.311787  0.265306             normal  Cleveland
#
#           f                g         h      i  ...         r       s  \
# 0  0.505577   typical angina  0.386401   True  ...  0.662431    Male
# 1  0.729423     asymptomatic  0.474295  False  ...  0.754496    Male
# 2  0.409365     asymptomatic  0.379768  False  ...  0.789172    Male
# 3  0.603448      non-anginal  0.414594  False  ...  0.192486    Male
# 4  0.368214  atypical angina  0.338308  False  ...  0.276569  Female
#
#           t         u      v         w         x         y        z      {
# 0  0.556818  0.674270  0.725  0.296233  0.000000  0.661761  0.76927  False
# 1  0.465909  0.493907  0.800  0.453651  1.000000  0.747905  0.76927   True
# 2  0.590909  0.738290  0.600  0.444626  0.666667  0.742166  0.76927   True
# 3  0.693182  0.202523  0.650  0.255787  0.000000  0.205487  0.76927  False
# 4  0.454545  0.493907  0.650  0.523153  0.000000  0.278658  0.76927  False
#
# [5 rows x 28 columns]

# %%
# 3. Save the cleaned dataset
clean_data.to_csv('../Data/clean_data.csv', index=False)

# %%
# 4. Train and evaluate the model
dp.simple_model(clean_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 2
#       1 # 4. Train and evaluate the model
# ----> 2 dp.simple_model(clean_data)
#
# File c:\Users\ruths\Documents\Clinical Bioinfo\Machine Learning\BINF-5507\Assignments\Assignment1\Assignment1\Scripts\data_preprocessor.py:127, in simple_model(input_data, split_data, scale_data, print_report)
#     124     X_train = normalize_data(X_train)
#     125     X_test = normalize_data(X_test)
# --> 127 # instantiate and fit the model
#     128 log_reg = LogisticRegression(random_state=42, max_iter=100, solver='liblinear', penalty='l2', C=1.0)
#     129 log_reg.fit(X_train, y_train)
#
# File c:\Users\ruths\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\ruths\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1215, in LogisticRegression.fit(self, X, y, sample_weight)
#    1205     _dtype = [np.float64, np.float32]
#    1207 X, y = self._validate_data(
#    1208     X,
#    1209     y,
#    (...)
#    1213     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1214 )
# -> 1215 check_classification_targets(y)
#    1216 self.classes_ = np.unique(y)
#    1218 multi_class = _check_multi_class(self.multi_class, solver, len(self.classes_))
#
# File c:\Users\ruths\anaconda3\Lib\site-packages\sklearn\utils\multiclass.py:215, in check_classification_targets(y)
#     207 y_type = type_of_target(y, input_name="y")
#     208 if y_type not in [
#     209     "binary",
#     210     "multiclass",
#    (...)
#     213     "multilabel-sequences",
#     214 ]:
# --> 215     raise ValueError(
#     216         f"Unknown label type: {y_type}. Maybe you are trying to fit a "
#     217         "classifier, which expects discrete classes on a "
#     218         "regression target with continuous values."
#     219     )
#
# ValueError: Unknown label type: continuous. Maybe you are trying to fit a classifier, which expects discrete classes on a regression target with continuous values.
